# %%
mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2048/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7529afa66959> in <module>()
# ----> 1 mfcc1 = librosa.feature.mfcc(y1, sr1)
#       2 mfcc1 = mfcc1/np.max(mfcc1)
#       3
#       4 mfcc3 = librosa.feature.mfcc(y3, sr3)
#       5 mfcc3 = mfcc3/np.max(mfcc3)
#
# NameError: name 'librosa' is not defined

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence3.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2048/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/librosa/core.py:25: UserWarning: Could not import scikits.samplerate. Falling back to scipy.signal
#   'Falling back to scipy.signal')
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence2.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(word)

# %%
plt.plot(dists3i)

# %%
mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)
mfccX = mfccX[:,20:]


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)

# %%
IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = 0
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence3.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = 19
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print word_samp_bounds[1] - word_samp_bounds[0]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
# 26624.0
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
# [251393.0, 229889.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = 19
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


ipython.display.audio(data=word, rate=sr1)

ipython.display.audio(data=mfcc1, rate=sr1)
# Out:
# [251393.0, 224769.0]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bbc01f294b93> in <module>()
#      28
#      29
# ---> 30 ipython.display.audio(data=word, rate=sr1)
#      31
#      32 ipython.display.audio(data=mfcc1, rate=sr1)
#
# NameError: name 'ipython' is not defined

# %%
ipython.display.audio(data=word, rate=sr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ecaa2a6e291d> in <module>()
#       1
# ----> 2 ipython.display.audio(data=word, rate=sr1)
#
# NameError: name 'ipython' is not defined

# %%
iPython.display.audio(data=word, rate=sr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c496697582c5> in <module>()
# ----> 1 iPython.display.audio(data=word, rate=sr1)
#
# NameError: name 'iPython' is not defined

# %%
IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=mfcc1, rate=sr1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2e20a631e07a> in <module>()
# ----> 1 IPython.display.Audio(data=mfcc1, rate=sr1)
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/lib/display.pyc in __init__(self, data, filename, url, embed, rate, autoplay)
#      85
#      86         if self.data is not None and not isinstance(self.data, bytes):
# ---> 87             self.data = self._make_wav(data,rate)
#      88
#      89     def reload(self):
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/lib/display.pyc in _make_wav(self, data, rate)
#     109             data = np.array(data,dtype=float)
#     110             if len(data.shape) > 1:
# --> 111                 raise ValueError("encoding of stereo PCM signals are unsupported")
#     112             scaled = np.int16(data/np.max(np.abs(data))*32767).tolist()
#     113         except ImportError:
#
# ValueError: encoding of stereo PCM signals are unsupported

# %%
IPython.display.Audio(data=word, rate=sr1)
IPython.display.Audio(data=y1, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=y3, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
# [254465.0, 234497.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [254465.0, 234497.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence4.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [182785.0, 162817.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(dists3i)

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence5.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [130049.0, 110081.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=word, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.25
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [130049.0, 108545.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(dists3i)

# %%
speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [94721.0, 73217.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = 29
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [96257.0, 64513.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence6.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [27649.0, 6145.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(dists3i)

# %%
speed = 59
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [125953.0, 78849.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(dists3i)

# %%
word_match_idx = 350#dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
# Out:
# [226305.0, 179201.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = 151
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [331265.0, 237057.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(dists3i)

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence5.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc3.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc3.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [94721.0, 73217.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
from dtw import dtw
import IPython.display
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


y1, sr1 = librosa.load('/Users/chris/Documents/audio_samples/elias_warping_cut.m4a')
y2, sr2 = librosa.load('/Users/chris/Documents/audio_samples/elias_leader_cut.m4a')
y3, sr3 = librosa.load('/Users/chris/Documents/audio_samples/chris_warping_cut.m4a')
y4, sr4 = librosa.load('/Users/chris/Documents/audio_samples/chris_follow_cut.m4a')
yX, srX = librosa.load('/Users/chris/Documents/audio_samples/full_sentence5.m4a')

#plt.close()
#plt.plot(y1,'b-')
#plt.plot(y2,'r-')
## remove mean


#n = 5
#subplot(1, n, 1)
#mfcc1 = librosa.feature.mfcc(y1, sr1)
#mfcc1 = mfcc1/np.max(mfcc1)
#librosa.display.specshow(mfcc1)
#
#subplot(1, n, 2)
#mfcc2 = librosa.feature.mfcc(y2, sr2)
#mfcc2 = mfcc2/np.max(mfcc2)
#librosa.display.specshow(mfcc2)
#
#subplot(1, n, 3)
#mfcc3 = librosa.feature.mfcc(y3, sr3)
#mfcc3 = mfcc3/np.max(mfcc3)
#librosa.display.specshow(mfcc3)
#
#subplot(1, n, 4)
#mfcc4 = librosa.feature.mfcc(y4, sr4)
#mfcc4 = mfcc4/np.max(mfcc4)
#librosa.display.specshow(mfcc4)
#
#subplot(1, n, 5)
#mfccX = librosa.feature.mfcc(yX, srX)
##mfccX = mfccX/np.max(mfccX)
#librosa.display.specshow(mfccX)
#
#
#from dtw import dtw
#
#
#dist12, cost12, path12 = dtw(mfcc1.T, mfcc2.T)
#dist13, cost13, path13 = dtw(mfcc1.T, mfcc3.T)
#dist14, cost14, path14 = dtw(mfcc1.T, mfcc4.T)
#dist24, cost24, path24 = dtw(mfcc2.T, mfcc4.T)
#dist23, cost23, path23 = dtw(mfcc2.T, mfcc3.T)
#dist34, cost34, path34 = dtw(mfcc3.T, mfcc4.T)
#print 'Normalized distance between the two sounds:', dist
#
#def show_image(dist,cost,path):
#    imshow(cost.T, origin='lower', cmap=cm.gray, interpolation='nearest')
#    plot(path[0], path[1], 'w')
#    xlim((-0.5, cost.shape[0]-0.5))
#    ylim((-0.5, cost.shape[1]-0.5))
#
#show_image(dist12, cost12, path12)
#show_image(dist13, cost13, path13)
#show_image(dist14, cost14, path14)
#show_image(dist23, cost23, path23)
#show_image(dist34, cost34, path34)


mfcc1 = librosa.feature.mfcc(y1, sr1)
mfcc1 = mfcc1/np.max(mfcc1)

mfcc3 = librosa.feature.mfcc(y3, sr3)
mfcc3 = mfcc3/np.max(mfcc3)


mfccX = librosa.feature.mfcc(yX, srX)
#mfccX = mfccX/np.max(mfccX)


#dists3i = np.zeros(mfccX.shape[1] - mfcc3.shape[1] + speed)
#dists3i = np.zeros(mfccX.shape[1] + mfcc3.shape[1] + speed) + 1.25

speed = 9
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [92673.0, 72705.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = -20
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [130049.0, 124929.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speed = -10
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [35841.0, 25601.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
window_size
# Out:
# 20

# %%
speed = 0
dists3i = np.zeros(mfccX.shape[1]) + 1.5
window_size = (mfcc1.shape[1]+speed)
for i in range(mfccX.shape[1] - window_size):

    mfcci = mfccX[:,i:i+window_size]
    mfcci = mfcci/np.max(mfcci)

    dist3i, cost3i, path3i = dtw(mfcc1.T, mfcci.T)
    dists3i[i] = dist3i

plt.plot(dists3i)

# 
#n_fft=2048
#hop_length=512
#

word_match_idx = dists3i.argmin()
word_match_idx_bnds = np.array([word_match_idx,np.ceil(word_match_idx+window_size)])
samples_per_mfcc = 512#len(yX)/mfccX.shape[1]
word_samp_bounds = (2/2) + (word_match_idx_bnds*samples_per_mfcc)

word = yX[word_samp_bounds[0]:word_samp_bounds[1]]
print [word_samp_bounds[1], word_samp_bounds[0]]

plt.plot(word)


IPython.display.Audio(data=word, rate=sr1)
#IPython.display.Audio(data=y1, rate=sr1)
# Out:
# [92673.0, 77313.0]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
